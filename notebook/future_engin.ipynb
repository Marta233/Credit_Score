# %% [markdown]
# ### Feature Engineering

# %%
import pandas as pd
import sys
sys.path.insert(0, '/10 A KAI 2/Week6/Credit_Scoring/')

# %%
from Script.Feature_engi import Feature_Engineering

# %%
df = pd.read_csv('../Data/data.csv')

# %%
fut_eng = Feature_Engineering(df)

# %% [markdown]
# ### Remove unneccery columns and only one values likr CountryCode

# %%
attrib=['BatchId',  'SubscriptionId', 'CurrencyCode', 'CountryCode', 'ProductId']
fut_eng.remove_some_cols(attrib)
# Out:
#               TransactionId       AccountId       CustomerId    ProviderId  \
# 0       TransactionId_76871  AccountId_3957  CustomerId_4406  ProviderId_6
# 1       TransactionId_73770  AccountId_4841  CustomerId_4406  ProviderId_4
# 2       TransactionId_26203  AccountId_4229  CustomerId_4683  ProviderId_6
# 3         TransactionId_380   AccountId_648   CustomerId_988  ProviderId_1
# 4       TransactionId_28195  AccountId_4841   CustomerId_988  ProviderId_4
# ...                     ...             ...              ...           ...
# 95657   TransactionId_89881  AccountId_4841  CustomerId_3078  ProviderId_4
# 95658   TransactionId_91597  AccountId_3439  CustomerId_3874  ProviderId_6
# 95659   TransactionId_82501  AccountId_4841  CustomerId_3874  ProviderId_4
# 95660  TransactionId_136354  AccountId_1346  CustomerId_1709  ProviderId_6
# 95661   TransactionId_35670  AccountId_4841  CustomerId_1709  ProviderId_4
#
# ...

# %% [markdown]
# #### Aggregate Credit and Debit transaction amount in the customer label
# 1. **Total Credit Amount**: Summed the values in the Credit column to determine the total credit transactions for each customer.
# 2. **Total Debit Amount**: Summed the values in the Debit column to determine the total debit transactions for each customer.
# 3. **Average Transaction Amount**: Calculated the mean of the Value column, which represents the average transaction value for each customer.
# 4.  **Transaction Count**: Counted the number of transactions per CustomerId using the TransactionId column.
# 5.  **Total Unique Account Count**: Counted the unique accounts associated with each customer using the AccountId column.
# 6.  **Standard Deviation of Transaction Amount**: Computed the standard deviation of the Amount column to assess the variability of transaction amounts. The ddof=0 parameter ensures a population standard deviation is calculated, and if there are fewer than two entries, NaN is replaced with zero.

# %%
df2 = fut_eng.feature_engineering_transaction()

# %%
df2.columns
# Out:
# Index(['CustomerId', 'Total_Credit_Amount', 'Total_Debit_Amount',
#        'Average_Transaction_Amount', 'Transaction_Count',
#        'Total_Unique_Account_Count', 'distinct_product_categories',
#        'Standard_Deviation_Transaction_Amount'],
#       dtype='object')

# %% [markdown]
# ##### The above result shows the aggrigation by customer. totally we have 3742 customer.

# %%
df
# Out:
#               TransactionId         BatchId       AccountId  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957
# 1       TransactionId_73770   BatchId_15642  AccountId_4841
# 2       TransactionId_26203   BatchId_53941  AccountId_4229
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 4       TransactionId_28195   BatchId_38780  AccountId_4841
# ...                     ...             ...             ...
# 95657   TransactionId_89881   BatchId_96668  AccountId_4841
# 95658   TransactionId_91597    BatchId_3503  AccountId_3439
# 95659   TransactionId_82501  BatchId_118602  AccountId_4841
# 95660  TransactionId_136354   BatchId_70924  AccountId_1346
# 95661   TransactionId_35670   BatchId_29317  AccountId_4841
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 0       SubscriptionId_887  CustomerId_4406          UGX          256
# 1      SubscriptionId_3829  CustomerId_4406          UGX          256
# ...

# %% [markdown]
# #### Extract Transaction day, year,  month and Hour fron trsnsaction date

# %%
fut_eng.extract_transaction_features()
# Out:
#               TransactionId       AccountId       CustomerId    ProviderId  \
# 0       TransactionId_76871  AccountId_3957  CustomerId_4406  ProviderId_6
# 1       TransactionId_73770  AccountId_4841  CustomerId_4406  ProviderId_4
# 2       TransactionId_26203  AccountId_4229  CustomerId_4683  ProviderId_6
# 3         TransactionId_380   AccountId_648   CustomerId_988  ProviderId_1
# 4       TransactionId_28195  AccountId_4841   CustomerId_988  ProviderId_4
# ...                     ...             ...              ...           ...
# 95657   TransactionId_89881  AccountId_4841  CustomerId_3078  ProviderId_4
# 95658   TransactionId_91597  AccountId_3439  CustomerId_3874  ProviderId_6
# 95659   TransactionId_82501  AccountId_4841  CustomerId_3874  ProviderId_4
# 95660  TransactionId_136354  AccountId_1346  CustomerId_1709  ProviderId_6
# 95661   TransactionId_35670  AccountId_4841  CustomerId_1709  ProviderId_4
#
#           ProductCategory    ChannelId   Amount  Value  \
# ...

# %% [markdown]
# #### Label encoding for column ProductCategory, ProviderId and ChannelId

# %%
column = ['ProductCategory',  'ChannelId', 'ProviderId']
fut_eng.label_encoding_selected_attribute(column)
# Out:
#               TransactionId       AccountId       CustomerId  ProviderId  \
# 0       TransactionId_76871  AccountId_3957  CustomerId_4406           5
# 1       TransactionId_73770  AccountId_4841  CustomerId_4406           3
# 2       TransactionId_26203  AccountId_4229  CustomerId_4683           5
# 3         TransactionId_380   AccountId_648   CustomerId_988           0
# 4       TransactionId_28195  AccountId_4841   CustomerId_988           3
# ...                     ...             ...              ...         ...
# 95657   TransactionId_89881  AccountId_4841  CustomerId_3078           3
# 95658   TransactionId_91597  AccountId_3439  CustomerId_3874           5
# 95659   TransactionId_82501  AccountId_4841  CustomerId_3874           3
# 95660  TransactionId_136354  AccountId_1346  CustomerId_1709           5
# 95661   TransactionId_35670  AccountId_4841  CustomerId_1709           3
#
#        ProductCategory  ChannelId   Amount  Value      TransactionStartTime  \
# ...

# %% [markdown]
# #### Scale continues cilumns

# %%
attrinutes = ['Total_Credit_Amount', 'Total_Debit_Amount','Average_Transaction_Amount', 'Transaction_Count','Total_Unique_Account_Count']
fut_eng.numeric_feature_scaling(attrinutes)
# Out:
#       Total_Credit_Amount  Total_Debit_Amount  Average_Transaction_Amount  \
# 0               -0.100614           -0.017562                   -0.052297
# 1               -0.100614           -0.017562                   -0.052297
# 2               -0.088647           -0.020360                   -0.075710
# 3               -0.098477           -0.023230                   -0.109431
# 4               -0.088267           -0.019893                   -0.080169
# ...                   ...                 ...                         ...
# 3737            -0.088267           -0.019893                   -0.080169
# 3738            -0.088267           -0.019893                   -0.073798
# 3739             0.173877           -0.003497                   -0.075710
# 3740            -0.031754           -0.019893                   -0.058972
# 3741            -0.038165           -0.005029                   -0.067772
#
#       Transaction_Count  Total_Unique_Account_Count
# ...
